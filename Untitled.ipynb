# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %% [raw]
# torch.cuda.get_device_name(0)

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 4060 Laptop GPU'

# %%
### Tensors

# %%
tensor = torch.Tensor([[1,2,3], [7,6,5]])
tensor
# Out:
# tensor([[1., 2., 3.],
#         [7., 6., 5.]])

# %%
tensor * 5
# Out:
# tensor([[ 5., 10., 15.],
#         [35., 30., 25.]])

# %%
tensor + 5
# Out:
# tensor([[ 6.,  7.,  8.],
#         [12., 11., 10.]])

# %%
tensor.sum()
# Out:
# tensor(24.)

# %%
torch.ones((2,3))
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.rand((2,4))
# Out:
# tensor([[0.5183, 0.4768, 0.0867, 0.3548],
#         [0.8029, 0.8022, 0.8054, 0.6780]])

# %%
tensor.shape
# Out:
# torch.Size([2, 3])

# %%
tensor.dtype
# Out:
# torch.float32

# %%
tensor.device
# Out:
# device(type='cpu')

# %%
tensor = tensor.to('cuda')

# %%
tensor.sum()
# Out:
# tensor(24., device='cuda:0')

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
a = torch.tensor([2., 3.], requires_grad=True)
b = torch.tensor([6., 4.], requires_grad=True)

f = 3 * a**3 - b**2

# %%
f
# Out:
# tensor([-12.,  65.], grad_fn=<SubBackward0>)

# %%
f.backward(gradient=torch.tensor([1,1]))

# %%
print(a.grad)
print(b.grad)
# Out:
# tensor([36., 81.])
# tensor([-12.,  -8.])

# %%
9 * a**2
# Out:
# tensor([36., 81.], grad_fn=<MulBackward0>)

# %%
import torch.nn as nn

# %%
import torch.nn.functional as F

# %%
import torch.optim as optim

# %%
from torch.utils.data import DataLoader, TensorDataset

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.21964471,  0.28477304, -0.14863849, ...,  1.35548576,
#          1.06018325,  1.45871554],
#        [-1.32663717, -0.78407494, -1.34037487, ..., -0.65778023,
#         -0.26517774, -0.12156867],
#        [-0.87234572, -1.21068672, -0.87801636, ..., -1.15776351,
#         -0.55490037, -0.75107749],
#        ...,
#        [-1.6142877 , -1.43558532, -1.57847063, ..., -0.46233222,
#          0.09657538,  1.13310753],
#        [-0.10123435,  1.0336622 , -0.02623715, ...,  1.29791193,
#          2.41595711,  1.33389913],
#        [-0.56332356, -1.20604964, -0.56195262, ..., -0.36718389,
#         -0.39323194,  0.22900262]], shape=(455, 30))

# %%
X_train_scaled.min()
print(X_train_scaled.min(axis=0))
print(f"Średnia: {X_train_scaled.mean():.2f}")
print(f"Odchylenie: {X_train_scaled.std():.2f}")
# Out:
# [-2.07348885 -2.22157115 -2.02867283 -1.4950095  -3.06842032 -1.60073497
#  -1.12847615 -1.27858946 -2.29986915 -1.76611601 -1.12778324 -1.54124222
#  -1.11659543 -0.79620889 -1.77725445 -1.33404883 -1.0199017  -1.85967186
#  -1.50134552 -1.14166742 -1.74699152 -2.23900706 -1.7205905  -1.23180582
#  -2.61991385 -1.44195524 -1.31962726 -1.75198605 -2.17318534 -1.57269504]
# Średnia: 0.00
# Odchylenie: 1.00

# %%
y_train
type(y_train)
# Out:
# numpy.ndarray

# %%
X_train_scaled_tensor = torch.from_numpy(X_train_scaled).float()
X_test_scaled_tensor = torch.from_numpy(X_test_scaled).float()
y_train_tensor = torch.from_numpy(y_train).float().unsqueeze(1)
y_test_tensor = torch.from_numpy(y_test).float().unsqueeze(1)

# %%
train_dataset = TensorDataset(X_train_scaled_tensor, y_train_tensor)

# %%
X_train_scaled_tensor.shape
# Out:
# torch.Size([455, 30])

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
class BCNet(nn.Module):

    def __init__(self):
        super(BCNet, self).__init__()

        self.fc1 = nn.Linear(30, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.sigmoid(self.fc3(x))

        return x

# %%
model = BCNet()

# %%
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

# %%
epochs = 20
for epoch in range(epochs):
    model.train()
    running_loss = 0.0

    for x_batch, y_batch in train_loader:
        optimizer.zero_grad()
        preds = model(x_batch)
        loss = criterion(preds, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f"Epoch {epoch+1}: Loss was {running_loss/len(train_loader)}")
# Out:
# Epoch 1: Loss was 0.6080779214700063
# Epoch 2: Loss was 0.4303367793560028
# Epoch 3: Loss was 0.25374808510144553
# Epoch 4: Loss was 0.14876430928707124
# Epoch 5: Loss was 0.10785101229945819
# Epoch 6: Loss was 0.07582854401941101
# Epoch 7: Loss was 0.06257936867574851
# Epoch 8: Loss was 0.05528876843551795
# Epoch 9: Loss was 0.05129621097197135
# Epoch 10: Loss was 0.04332809224724769
# Epoch 11: Loss was 0.03806415063639482
# Epoch 12: Loss was 0.037858065435041985
# Epoch 13: Loss was 0.03134007342159748
# Epoch 14: Loss was 0.03037424509723981
# Epoch 15: Loss was 0.02794178482145071
# Epoch 16: Loss was 0.025034598633646966
# Epoch 17: Loss was 0.02280734235343213
# Epoch 18: Loss was 0.022175487767284115
# Epoch 19: Loss was 0.0200491783907637
# Epoch 20: Loss was 0.017925730188532423

# %%
with torch.no_grad():
    model.eval()
    preds = model(X_test_scaled_tensor)
    loss = criterion(preds, y_test_tensor).item()
    accuracy = ((preds >= 0.5) == y_test_tensor).float().mean().item()

# %%
accuracy
# Out:
# 0.9649122953414917
