# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %% [raw]
# torch.cuda.get_device_name(0)

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 4060 Laptop GPU'

# %%
### Tensors

# %%
tensor = torch.Tensor([[1,2,3], [7,6,5]])
tensor
# Out:
# tensor([[1., 2., 3.],
#         [7., 6., 5.]])

# %%
tensor * 5
# Out:
# tensor([[ 5., 10., 15.],
#         [35., 30., 25.]])

# %%
tensor + 5
# Out:
# tensor([[ 6.,  7.,  8.],
#         [12., 11., 10.]])

# %%
tensor.sum()
# Out:
# tensor(24.)

# %%
torch.ones((2,3))
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.rand((2,4))
# Out:
# tensor([[0.5654, 0.4168, 0.0318, 0.0840],
#         [0.8559, 0.8816, 0.3403, 0.0289]])

# %%
tensor.shape
# Out:
# torch.Size([2, 3])

# %%
tensor.dtype
# Out:
# torch.float32

# %%
tensor.device
# Out:
# device(type='cpu')

# %%
tensor = tensor.to('cuda')

# %%
tensor.sum()
# Out:
# tensor(24., device='cuda:0')

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
a = torch.tensor([2., 3.], requires_grad=True)
b = torch.tensor([6., 4.], requires_grad=True)

f = 3 * a**3 - b**2

# %%
f
# Out:
# tensor([-12.,  65.], grad_fn=<SubBackward0>)

# %%
f.backward(gradient=torch.tensor([1,1]))

# %%
print(a.grad)
print(b.grad)
# Out:
# tensor([36., 81.])
# tensor([-12.,  -8.])

# %%
9 * a**2
# Out:
# tensor([36., 81.], grad_fn=<MulBackward0>)

# %%
import torch.nn as nn

# %%
import torch.nn.functional as F

# %%
import torch.optim as optim

# %%
from torch.utils.data import DataLoader, TensorDataset

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X, y = load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-5.98614878e-01, -1.51851112e+00, -6.37087771e-01, ...,
#         -7.12344163e-01, -6.38320329e-01, -2.83842435e-01],
#        [-7.31065939e-01, -2.03194794e-01, -7.60659802e-01, ...,
#         -5.17359837e-01,  4.81922191e-01, -3.03027815e-01],
#        [ 3.19063720e+00,  1.32978064e+00,  3.31471238e+00, ...,
#          2.62925183e+00, -8.94237802e-01,  1.14793511e+00],
#        ...,
#        [ 7.08619502e-01,  2.07169394e+00,  6.76282529e-01, ...,
#          3.92258254e-01, -1.11474531e+00, -3.26598426e-01],
#        [-6.88106358e-02,  2.76221058e-03, -1.40712283e-01, ...,
#         -5.38664538e-01, -8.92628258e-01, -4.45547785e-01],
#        [ 9.79280365e-01,  2.14855746e-02,  9.60164222e-01, ...,
#          1.19658790e+00,  2.80308252e-02, -3.00835200e-01]],
#       shape=(455, 30))

# %%
y_train
type(y_train)
# Out:
# numpy.ndarray

# %%
X_train_scaled_tensor = torch.from_numpy(X_train_scaled).float()
X_test_scaled_tensor = torch.from_numpy(X_test_scaled).float()
y_train_tensor = torch.from_numpy(y_train).float().unsqueeze(1)
y_test_tensor = torch.from_numpy(y_test).float().unsqueeze(1)

# %%
train_dataset = TensorDataset(X_train_scaled_tensor, y_train_tensor)

# %%
X_train_scaled_tensor.shape
# Out:
# torch.Size([455, 30])

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
class BCNet(nn.Module):

    def __init__(self):
        super(BCNet, self).__init__()

        self.fc1 = nn.Linear(30, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.sigmoid(self.fc3(x))

        return x

# %%
model = BCNet()

# %%
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

# %%
epochs = 20
for epoch in range(epochs):
    model.train()
    running_loss = 0.0

    for x_batch, y_batch in train_loader:
        optimizer.zero_grad()
        preds = model(x_batch)
        loss = criterion(preds, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f"Epoch {epoch+1}: Loss was {running_loss/len(train_loader)}")
# Out:
# Epoch 1: Loss was 0.5682909329732259
# Epoch 2: Loss was 0.369841347138087
# Epoch 3: Loss was 0.22837866147359212
# Epoch 4: Loss was 0.1424987609187762
# Epoch 5: Loss was 0.10922542810440064
# Epoch 6: Loss was 0.0872782178223133
# Epoch 7: Loss was 0.07490228898823262
# Epoch 8: Loss was 0.06809973331789175
# Epoch 9: Loss was 0.05969324459632238
# Epoch 10: Loss was 0.05471204991141955
# Epoch 11: Loss was 0.05172905611495177
# Epoch 12: Loss was 0.046700090542435645
# Epoch 13: Loss was 0.044023157314707836
# Epoch 14: Loss was 0.041219536354765295
# Epoch 15: Loss was 0.03949890658259392
# Epoch 16: Loss was 0.03959794845432043
# Epoch 17: Loss was 0.0353797385469079
# Epoch 18: Loss was 0.033217985865970454
# Epoch 19: Loss was 0.044634756011267505
# Epoch 20: Loss was 0.048064693063497546

# %%
with torch.no_grad():
    model.eval()
    preds = model(X_test_scaled_tensor)
    loss = criterion(preds, y_test_tensor).item()
    accuracy = ((preds >= 0.5) == y_test_tensor).float().mean().item()

# %%
accuracy
# Out:
# 0.9561403393745422
